# %% [markdown]
# #### 지도 시각화
#
# - pip install folium
# - pip install branca

# %%
import folium
import branca
from folium import plugins

# %%
m = folium.Map(location=[37.566697,126.978426])
m

# %%
m = folium.Map(
    location=[37.566697,126.978426],
    tiles="Stamen Terrain",
    zoom_start=15
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7c364fe6b20bd0e164587dbc105cfca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7c364fe6b20bd0e164587dbc105cfca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7c364fe6b20bd0e164587dbc105cfca = L.map(
#                 &quot;map_a7c364fe6b20bd0e164587dbc105cfca&quot;,
#                 {
#                     center: [37.566697, 126.978426],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5918d930e984e769d1f49dc4acc3952a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a7c364fe6b20bd0e164587dbc105cfca);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[37.566697,126.978426],
    tiles="Stamen Terrain",
    zoom_start=12
)

# 마커지정
tooltip = "Click me!!"

folium.Marker(
    # 돈의문 박물관
    [37.5687865,126.9685111],
    popup="<i>돈의문 박물관</i>",
    tooltip=tooltip
).add_to(m)

folium.Marker(
    [37.5693255,126.9860066],
    popup="<i>솔데스크</i>",
    tooltip=tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2d28d39c2f129a2758802a24dc96627 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2d28d39c2f129a2758802a24dc96627&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2d28d39c2f129a2758802a24dc96627 = L.map(
#                 &quot;map_f2d28d39c2f129a2758802a24dc96627&quot;,
#                 {
#                     center: [37.566697, 126.978426],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39779a78e04718103ac88332ef738f63 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f2d28d39c2f129a2758802a24dc96627);
#
#
#             var marker_408d7373261de791db086e7669408d69 = L.marker(
#                 [37.5687865, 126.9685111],
#                 {}
#             ).addTo(map_f2d28d39c2f129a2758802a24dc96627);
#
#
#         var popup_f8d845df92b629f53adc6aac35c2f227 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e01ee355046ee05a4cbee3c3648370a6 = $(`&lt;div id=&quot;html_e01ee355046ee05a4cbee3c3648370a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;돈의문 박물관&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_f8d845df92b629f53adc6aac35c2f227.setContent(html_e01ee355046ee05a4cbee3c3648370a6);
#
#
#
#         marker_408d7373261de791db086e7669408d69.bindPopup(popup_f8d845df92b629f53adc6aac35c2f227)
#         ;
#
#
#
#
#             marker_408d7373261de791db086e7669408d69.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cbf5f5c5a641207a717d85f84064d08a = L.marker(
#                 [37.5693255, 126.9860066],
#                 {}
#             ).addTo(map_f2d28d39c2f129a2758802a24dc96627);
#
#
#         var popup_4f4688c35ffccab34af3a78585ad3766 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e7131650b45cb905a229edfbb99183a = $(`&lt;div id=&quot;html_0e7131650b45cb905a229edfbb99183a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;솔데스크&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_4f4688c35ffccab34af3a78585ad3766.setContent(html_0e7131650b45cb905a229edfbb99183a);
#
#
#
#         marker_cbf5f5c5a641207a717d85f84064d08a.bindPopup(popup_4f4688c35ffccab34af3a78585ad3766)
#         ;
#
#
#
#
#             marker_cbf5f5c5a641207a717d85f84064d08a.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 마커 + 아이콘

m = folium.Map(
    location=[37.566697,126.978426],
    tiles="Stamen Terrain",
    zoom_start=12
)

# 마커지정
tooltip = "Click me!!"

folium.Marker(
    # 돈의문 박물관
    [37.5687865,126.9685111],
    popup="<i>돈의문 박물관</i>",
    icon=folium.Icon(color="red",icon="info-sign"),
    tooltip=tooltip
).add_to(m)

folium.Marker(
    [37.5693255,126.9860066],
    popup="<i>솔데스크</i>",
    icon=folium.Icon(color="blue",icon="star"),
    tooltip=tooltip
).add_to(m)

folium.Marker(
    [37.5716352,126.9767435],
    popup="<i>광화문광장</i>",
    icon=folium.Icon(color="blue",icon="bookmark"),
    tooltip=tooltip
).add_to(m)

m

# %%
m = folium.Map(
    location=[37.566697,126.978426],
    tiles="Stamen Terrain",
    zoom_start=12
)

icon_plane = plugins.BeautifyIcon(
    icon="plane",border_color='darkblue',text_color='darkblue',icon_shape='circle'
)

folium.Marker(
    [37.562402,126.081289],
    popup="<i>김포공항</i>",
    icon=icon_plane
).add_to(m)

folium.Marker(
    # 돈의문 박물관
    [37.5687865,126.9685111],
    popup="<i>돈의문 박물관</i>",
    icon=folium.Icon(color="red",icon="info-sign"),
).add_to(m)

folium.Marker(
    [37.5693255,126.9860066],
    popup="<i>솔데스크</i>",
    icon=folium.Icon(color="blue",icon="star"),
).add_to(m)

folium.Marker(
    [37.5716352,126.9767435],
    popup="<i>광화문광장</i>",
    icon=folium.Icon(color="blue",icon="bookmark"),
).add_to(m)

m

# %%
m = folium.Map(
    location=[37.566697,126.978426],
    tiles="Stamen Terrain",
    zoom_start=12
)

folium.Marker(
    # 돈의문 박물관
    [37.5687865,126.9685111],
    popup="<i>돈의문 박물관</i>"
).add_to(m)

m.add_child(folium.ClickForMarker(popup="Marker"))

# %%
m = folium.Map(
    location=[37.566697,126.978426],
    zoom_start=15
)

folium.Circle(
    # 돈의문 박물관
    [37.5687865,126.9685111],
    popup="<i>돈의문 박물관</i>",
    radius = 60,
    color="royalblue",
    fill=True,
    fill_color="darkblue"
).add_to(m)
m

# %%
cities = [
    [37.566687,126.978417],
    [37.179774,129.075004],
    [37.455900,128.705522],
    [36.350451,127.384827],
    [35.160072,126.851440],
]


m = folium.Map(
    location=[37.566697,126.978426],
    zoom_start=7
)

for i in range(len(cities)):
    folium.Circle(
        location=cities[i],
        radius = 200,
        color="red",
    ).add_to(m)
m
