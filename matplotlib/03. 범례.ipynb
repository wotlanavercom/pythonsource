# %% [markdown]
# ## matplotlib (https://matplotlib.org/stable/index)
#
# - 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %% [markdown]
# ### 범례 설정
# - https://matplotlib.org/stable/api/legend_api.html

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["axes.unicode_minus"] = False

# %%
x = [1,2,3]
y = [2,4,8]

# %%
plt.plot(x,y, label="데이터")
plt.legend()
plt.show()

# %% [markdown]
# - 두 개의 선을 하나의 차트에 그릴 때

# %%
x1 = [1,2,3]
y1 = [1,4,7]

# %%
plt.plot(x,y, label="data1", color="blue")
plt.plot(x1,y1, label="data2", color="red")
plt.legend()
plt.show()

# %%
plt.plot(x,y, color="blue")
plt.plot(x1,y1, color="red")
plt.legend(['data1','data2'])
plt.show()

# %% [markdown]
# ><b>1) 범례 위치 설정</b>

# %% [markdown]
# - 범례 위치 지정하기 - 기본은 5
# - 0 or 아무값도 안 주면 그래프에 따라 자동으로 위치 지정
#
# <table border="1" align="left">
#     <tr>
#         <td>2(upper left)</td>
#         <td>9(upper center)</td>
#         <td>1(upper right)</td>
#     </tr>
#     <tr>
#         <td>6(center left)</td>
#         <td>10(center)</td>
#         <td>5(right),7(center right)</td>
#     </tr>
#     <tr>
#         <td>3(lower left)</td>
#         <td>8(lower center)</td>
#         <td>4(lower right)</td>
#     </tr>
# </table>
#
# <br><br>

# %%
plt.plot(x,y, color="blue")
plt.plot(x1,y1, color="red")
plt.legend(['data1','data2'],loc="upper right")
plt.show()

# %%
plt.plot(x,y, color="blue")
plt.plot(x1,y1, color="red")
plt.legend(['data1','data2'],loc=(0.5,0.5)) # x축, y축(0~1 사이 값 사용)
plt.show()

# %% [markdown]
# ><b>2) 범례 폰트 사이즈 지정</b>

# %%
plt.plot(x,y, color="blue")
plt.plot(x1,y1, color="red")
plt.legend(['data1','data2'], fontsize=16)
plt.show()

# %% [markdown]
# ><b>3) 범례 행 수 지정</b>

# %%
plt.plot(x,y, color="blue")
plt.plot(x1,y1, color="red")
plt.legend(['data1','data2'], fontsize=16, ncol=2)
plt.show()

# %% [markdown]
# - [문제] : data1(x : 1, 2, 3; y : 1, 2, 3) 과 data2(x : 1, 2, 3; y : 1, 100, 200) 을 그래프로 출력하시오.

# %%
# 범례, red/blue, 제목 : 선차트

plt.plot([1,2,3],[1,2,3],color="red")
plt.plot([1,2,3],[1,100,200],color="blue")
plt.title("선차트")
plt.legend(["data1","data2"])
plt.show()
