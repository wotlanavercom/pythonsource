# %%
# 크롤링 라이브러리
# requests, BeautipleSoup, Selenium, Scrapy....

# 파이썬 라이브러리 사용할 수도 있으나 외부 라이브러리를 주로 사용함

# requests : 특정 url 에서 정보를 가져오기 쉽게 도와주는 라이브러리

# %%
import requests

urls = ["https://www.python.org/","https://www.naver.com/"]

name = "robots.txt"

for url in urls:
    print(url+name)
    robots = requests.get(url+name)
    print(robots.text)
# Out:
# https://www.python.org/robots.txt
# # Directions for robots.  See this URL:
# # http://www.robotstxt.org/robotstxt.html
# # for a description of the file format.
#
# User-agent: HTTrack
# User-agent: puf
# User-agent: MSIECrawler
# Disallow: /
#
# # The Krugle web crawler (though based on Nutch) is OK.
# User-agent: Krugle
# Allow: /
# Disallow: /~guido/orlijn/
# Disallow: /webstats/
#
# # No one should be crawling us with Nutch.
# User-agent: Nutch
# Disallow: /
#
# # Hide old versions of the documentation and various large sets of files.
# User-agent: *
# Disallow: /~guido/orlijn/
# Disallow: /webstats/
#
# https://www.naver.com/robots.txt
# User-agent: *
# Disallow: /
# Allow : /$

# %%
import urllib.request as req

url = "https://google.com"

save_file = "./google.html"

try:
    file1, header1 = req.urlretrieve(url,save_file)
except Exception as e:
    print(e)
else:
    print(header1)
    print(file1)
    print("성공")
# Out:
# Date: Thu, 06 Jul 2023 07:18:04 GMT
# Expires: -1
# Cache-Control: private, max-age=0
# Content-Type: text/html; charset=ISO-8859-1
# Content-Security-Policy-Report-Only: object-src 'none';base-uri 'self';script-src 'nonce-kJzSrHhzFVq1Ij-vTOtEPQ' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other-hp
# P3P: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# Server: gws
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Set-Cookie: 1P_JAR=2023-07-06-07; expires=Sat, 05-Aug-2023 07:18:04 GMT; path=/; domain=.google.com; Secure
# Set-Cookie: AEC=Ad49MVGf8HWIl9JRC_REz1A-NjIxq61LUOgm0Z-a2dnN7--gQZx_oy3d1f4; expires=Tue, 02-Jan-2024 07:18:04 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax
# Set-Cookie: NID=511=ReaP8VInaMwUtdgr00nCRoyDSC9MGQLYCEaOf9keKDmL-PWPEH1aCjTVDljHydnb5zoEO4M3Dlnjc2mJbnZcRnkgIG6r252sT-DTyux_dxskth6wF-lRQZkbe9eC1vSo8Sa9fjOOqKzET868w8TFobCT6-T01V8ImuNr3zADX6I; expires=Fri, 05-Jan-2024 07:18:04 GMT; path=/; domain=.google.com; HttpOnly
# Alt-Svc: h3=":443"; ma=2592000,h3-29=":443"; ma=2592000
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close
# Transfer-Encoding: chunked
#
#
# ./google.html
# 성공

# %% [markdown]
# ##### urlretrieve
#     - 요청하는 url의 정보를 로컬 파일로 저장
#     - 튜플로 반환됨
#     - csv, api 데이터 등 많은 양의 데이터를 한번에 저장할 때 사용

# %%
img_url = "https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzA2MDhfMjcy%2FMDAxNjg2MjAzMzc5MzAw.jmzC3XmdcjWx5AoBRAzBn_Bu1vz_Of8pe5a-yXc7fgcg.kmHBPTxoaUx3vK-HyBwdJ0NWLdM9LOPEaCj7ynk7iNsg.JPEG.flaress2%2FKakaoTalk_20230608_143507325.jpg&type=a340"
html_url = "https://www.naver.com"

#경로
imge_path = "./cat.jpg"
html_path = "./naver.html"

try:
    file1, header1 = req.urlretrieve(img_url,imge_path)
    file2, header3 = req.urlretrieve(html_url,html_path)
except Exception as e:
    print(e)
else:
    print("filel {}".format(file1))
    print("file2 {}".format(file2))
# Out:
# filel ./cat.jpg
# file2 ./naver.html

# %% [markdown]
# ##### 다운로드는 필요없고 내용만 분석하고 싶을 때
#     - urlopen(), read()

# %%
weather_url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109"

data = req.urlopen(weather_url).read()

text = data.decode("utf-8")
print(text)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2023년 07월 06일 (목)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>서울,경기도 육상 중기예보 - 2023년 07월 06일 (목)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</guid>
# <description>
# 	<header>
# 		<title>서울,경기도 육상중기예보</title>
# 		<tm>202307060600</tm>
# 		<wf><![CDATA[○ (강수) 9일(일)~11일(화)과 14일(금)은 소나기가, 15일(토)은 비가 내리는 곳이 있겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~25도로 평년(최저기온 20~22도)보다 높겠고, 낮 기온은 26~31도로 평년(최고기온 27~30도)과 비슷하겠습니다.<br />○ (해상) 서해중부해상의 물결은 12일(수)~14일(금) 1.5~3.0m로 높게 일겠고, 그 밖의 날은 0.5~2.0m로 일겠습니다.<br />○ (주말전망) 8일(토)과 9일(일)은 대체로 흐리겠고, 9일은 소나기가 내리는 곳이 있겠습니다. 아침 기온은 21~24도, 낮 기온은 26~31도가 되겠습니다.<br /><br />* 우리나라 주변 기압계 변화에 따라 날씨 변동성이 큰 가운데, 비나 소나기가 내리는 지역과 시점이 변경될 가능성이 있겠으니 앞으로 발표되는 예보와 기상정보를 참고하기 바랍니다.]]></wf>
# 	</header>
# 	<body>
#
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>서울</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>인천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>수원</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>파주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>이천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>평택</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>백령도</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>21</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>20</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>과천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>광명</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>강화</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>김포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>시흥</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>안산</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>부천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>의정부</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>고양</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>양주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>동두천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# ...
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>군포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>안성</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>용인</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>광주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>여주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
#
# 	</body>
# </description>
# </item>
# </channel>
# </rss>

# %%
url = "https://www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&xfrom=main^gnb"

try:
    res = req.urlopen(url)
    contents = res.read().decode("euc-kr")
except Exception as e:
    print(e)
else:
    print(res.info())
    print(contents[:4000])
# Out:
# Date: Thu, 06 Jul 2023 07:57:24 GMT
# Content-Type: text/html;charset=EUC-KR
# Set-Cookie: JSESSIONID=C948CC625F13B2AFBEB5008EFF32CE3E.Tomcat; Path=/; HttpOnly
# Vary: Accept-Encoding,User-Agent
# Access-Control-Allow-Credentials: true
# Transfer-Encoding: chunked
# Connection: close
# Server: Apache
#
#
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
#
#
#
# <html lang="ko">
# <head>
#
# <title>11번가 베스트 | 11번가</title>
# <meta name="Title" content="11번가 베스트 | 11번가">
# <meta name="Description" content=" 베스트! 다른 사람들은 지금 뭘 살까? 11번가 추천하는 실시간  베스트 아이템 순위!">
# <meta name="Keywords" content=" | 11번가">
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <link rel="canonical" href="//www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&xfrom=main^gnb"/><link rel="alternate" media="only screen and (max-width: 640px)" href="//m.11st.co.kr/page/main/rank"/>
#
#
#
# <script type="text/javascript" src="//c.011st.com/html/experiment/experimentMetaInfo.js"></script>
#
# <script type="text/javascript" src="//c.011st.com/js/plab/plab-web-sdk-0.9.1.min.js"></script>
#
# <script>
#
#     var plabPageKey = '/best200/category';
#     try{
#
#         var params = {
#             projectKey : "11st_web",
#             domain : "11st.co.kr"
#         };
#         plab.initBy(params, experimentMetaInfo);
#
#     }catch (e) { console.log(e) };
#
#
# </script>
#
# <script type="text/javascript">
# 	!function(f,b,e,v,n,t,s) {if(f.fbq)return;n=f.fbq=function(){n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}; if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0'; n.queue=[];t=b.createElement(e);t.async=!0; t.src=v;s=b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t,s)}(window, document,'script', 'https://connect.facebook.net/en_US/fbevents.js');
# 	try {
# 		fbq('init', '2299486926950990');
# 		fbq('track', 'PageView');
# 	} catch (e) {
# 		console.error(e);
# 	}
# </script>
# <noscript>
# 	<img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=2299486926950990&ev=PageView&noscript=1"/>
# </noscript>
# <script async src="https://www.googletagmanager.com/gtag/js?id=AW-876562370"></script>
# <script>
# 	try{
# 		window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments);}
# 		gtag('js', new Date());
# 		gtag('config', 'AW-876562370');
# 	} catch(e) {}
# </script>
#
#
# <script type="text/javascript">
#
#
# 	// Global Var
# 	var _IMG_PATH_  = "//s.011st.com";
# 	var _UPLOAD_IMG_PATH_  = "http://image.11st.co.kr";
# 	var _SSL_UPLOAD_IMG_PATH_ = "https://www.11st.co.kr/is";
# 	var _ACTION_CONTEXT_  = "";
# 	var _FILE_UPLOAD_PATH_ = "http://image.11st.co.kr";
# 	var _GNB_CONTEXT_PATH_ = "//www.11st.co.kr";
# 	var _ACTION_CONTEXT_URL_ = "http://www.11st.co.kr";
# 	var _SSL_ACTION_CONTEXT_URL_ = "https://www.11st.co.kr";
# 	var _SSL_IMG_PATH_ = "//s.011st.com";
# 	var _GLOBAL_CONTEXT_PATH_ = "http://globalshopping.11st.co.kr";
# 	var _BEAUTY_CONTEXT_PATH_ = "http://beauty.11st.co.kr";
# 	var _SOHO_CONTEXT_PATH_ = "http://soho.11st.co.kr";
# 	var _JS_PATH_ = "//c.011st.com";
# 	var _SSL_JS_PATH_ = "//c.011st.com";
#
# 	var _GNB_LOGIN_URL_ = "https://login.11st.co.kr/login/Login.tmall";
# 	var _GNB_LOGOUT_URL_ = "https://login.11st.co.kr/login/Logout.tmall";
# 	var _PRODUCT_DETAIL_URL_ = "https://www.11st.co.kr/product/SellerProductDetail.tmall?method=getSellerProductDetail&prdNo=";
#
# 	var _ENJOY_SEARCH_VAR_ = "NONE";
# 	var _ENJOY_SEARCH_KEY_YN_ = "N";
#
# 	var _SELLER_SHOP_DOMAIN_ = "https://shop.11st.co.kr";
#
# 	// 변경 권고
# 	var _CSS_URL_			= "//c.011st.com";
# 	var _SSL_CSS_URL_		= "//c.011st.com";
# 	var _IMG_URL_			= "//s.011st.com";
# 	var _SSL_IMG_URL_		= "//s.011st.com";
# 	var _UPLOAD_URL_		= "http://i.011st.com";
# 	var _SSL_UPLOAD_URL_	= "https://i.011st.com";
#
# 	var _LOGIN_TARGET_URL_ 	= "https://login.11st.co.kr";
#
# 	// TZONE Var
# 	var _TZONE_URL_			= "http://skt.11st.co.kr";
# 	var _TZONE_URL_HOME_	= "http://skt.11st.co.kr/html/tzone/tZoneMain.html";
# 	var _SELLER_URL_		= "http://seller.11st.co.kr";
# 	var _SOFFICE_URL_		= "http://soffice.11st.co.kr";
# 	var _DS_URL_			= "http://ds.11st.co.kr";
# 	var _MY11ST_URL_		= "http://buy.11st.co.kr/order/myTmall.tmall?method=getMyTmallMain";
# 	var _SHOPPINGCART_URL_ 	= "http://buy.11st.co.kr/cart/CartAction.tmall?method=getCartList";
# 	var _MYSELL_U

# %%
news_url = "https://sports.news.naver.com/news?oid=014&aid=0005038179"

try:
    res = req.urlopen(news_url)
    content = res.read().decode("utf-8")
except Exception as e:
    print(e)
else:
    print(res.info())
    print(content[:4000])
# Out:
# date: Thu, 06 Jul 2023 08:07:27 GMT
# content-type: text/html;charset=UTF-8
# transfer-encoding: chunked
# x-xss-protection: 1; mode=block
# cache-control: no-store
# content-language: ko
# x-proxy-cache: HIT
# x-rate-limit: NORMAL_CACHE
# referrer-policy: unsafe-url
# server: nfront
# connection: close
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# 	<meta charset="UTF-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta http-equiv="X-UA-Compatible" content="requiresActiveX=true">
# 	<meta name="viewport" content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes">
#
#
# 			<meta property="me:feed:serviceId" content="sports"/>
# 			<meta property="me:feed:feedGroupId" content="sports"/>
# 			<meta property="me:feed:feedId" content=""/>
# 			<meta property="me:feed:feedName" content=""/>
# 			<meta property="me:feed:feedGroupName" content=""/>
# 			<meta property="me:feed:url" content=""/>
# 			<meta property="og:update_time" content="20230706161608"/>
# 			<meta property="article:contentLocation:name" content=""/>
# 			<meta property="article:contentLocation:url" content=""/>
#
# 		<meta property="og:type"        content="article"/>
# 		<meta property="og:image"       content="https://imgnews.pstatic.net/image/014/2023/07/06/0005038179_001_20230706170501591.jpg" />
# 		<meta property="og:title"       content="KIA의 광폭 행보가 무섭다. 5강 그 이상 노리나. 김태군, 산체스 이어 파노니까지 영입"/>
# 		<meta property="og:description" content="KIA 토마스 파노니가 한국으로 돌아온다는 소문이 파다하다 (사진 = 뉴스1) [파이낸셜뉴스 = 전상일 기자] 기아의 의지가 무섭다. 통상적인 9위팀의 그것이라고 보기에는 상당히 적극적이다. 기아는 7월 5일 오전 김태군과 류지혁을 맞트레이드 했다. KIA는 김태군을 영입하면서 안방에 대한 걱정을 완전히 덜었다. 타 팀에..."/>
# 		<meta property="og:url"         content="https://sports.news.naver.com/news?oid=014&aid=0005038179"/>
# 		<meta property="og:article:author" content="네이버 스포츠 | 파이낸셜뉴스"/>
# 		<meta property="og:article:author:url" content="https://sports.news.naver.com"/>
# 		<meta property="og:article:thumbnailUrl" content="https://imgnews.pstatic.net/image/sports/common/naverme/image-sports.png"/>
# 		<meta name="napp-site-analysis" content="gdid=880000FF_000000000000000005038179,service=sports,collection=news,section=107"/>
#
#
#
#
# 			<title>KIA의 광폭 행보가 무섭다. 5강 그 이상 노리나. 김태군, 산체스 이어 파노니까지 영입</title>
#
#
# 	<link rel="shortcut icon" href="/favicon.ico?v=20140331" otype="image/x-icon">
# 	<link rel="apple-touch-icon" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS6_57X57_iphone3.png">
# 	<link rel="apple-touch-icon" sizes="76x76" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS7_76X76_ipad.png">
# 	<link rel="apple-touch-icon" sizes="120x120" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS7_120X120_iphone.png">
# 	<link rel="apple-touch-icon" sizes="152x152" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS7_152X152_ipad_retina.png">
# 	<link rel="apple-touch-icon" sizes="167x167" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS_167X167_iPadPro.png"> <!-- 레티나 패드 -->
# 	<link rel="apple-touch-icon" sizes="180x180" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS_180X180_iPhone.png"> <!-- 레티나 패드 -->
# 	<content tag="css">
# 		<link rel='stylesheet' type='text/css' href='https://ssl.pstatic.net/static.sports/resources/pc/292929/66/298/665600/css/generated/nsportsCss.css'>
#
# 		<link rel='stylesheet' type='text/css' href='https://ssl.pstatic.net/static.sports/resources/pc/292929/66/298/665600/css/generated/newsEndOg.css'>
#
# 	</content>
# 	<script type='text/javascript' src='https://ssl.pstatic.net/static.sports/resources/pc/292929/66/298/665600/js/generated/newsCommon.js' charset='UTF-8'></script>
#
#
#
# <script>
# 	try {
# 		var deployPhase = 'release';
# 		if (deployPhase === 'release') {
# 			JEagleEyeClient.attachOnError();
#
# 		} else if (deployPhase === 'dev') {
# 			JEagleEyeClient.setDebugOnly(true);
# 			JEagleEyeClient.attachOnError();
#
# 		} else {
# 			// local
# 			JEagleEyeClient.attachOnError();
# 		}
# 	} catch (e) {
# 		console.log(e);
# 	}
# </script>
#
# 	<script type="text/javascript" language="javascript">
# 		var sports_category="";
# 		var ccsrv="cc.naver.com";
# 		var nsc = "sports.baseball";
# 		var gdid = "880000FF_000000000000000005038179";
# 	</script>
# </head>
# <body>
#
# <div id="u_skip">
# 	<a href="#lnb_main_sub" onclick="document.getElementById('lnb_m
